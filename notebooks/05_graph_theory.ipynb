# %% [markdown]
# # Graph Theory
#
# Graphs, representations, traversals (BFS/DFS), connectivity, and basic properties.

# %% [markdown]
# ## 1. Graph Representation
#
# We represent a graph using an adjacency list (a dictionary mapping each vertex to its neighbours).

# %%
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E'],
}

def degree(graph, vertex):
    return len(graph[vertex])

for v in graph:
    print(f"deg({v}) = {degree(graph, v)}")

total_degree = sum(degree(graph, v) for v in graph)
print(f"\nSum of degrees = {total_degree} = 2 × |edges|")
# Out:
# deg(A) = 2
# deg(B) = 3
# deg(C) = 2
# deg(D) = 1
# deg(E) = 2
# deg(F) = 2
#
# Sum of degrees = 12 = 2 × |edges|

# %% [markdown]
# ## 2. Breadth-First Search (BFS)
#
# BFS explores vertices level by level using a queue.

# %%
from collections import deque

def bfs(graph, start):
    visited = []
    seen = {start}
    queue = deque([start])
    while queue:
        node = queue.popleft()
        visited.append(node)
        for neighbour in graph[node]:
            if neighbour not in seen:
                seen.add(neighbour)
                queue.append(neighbour)
    return visited

print("BFS from A:", bfs(graph, 'A'))
# Out:
# BFS from A: ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# ## 3. Depth-First Search (DFS)
#
# DFS explores as far as possible along each branch before backtracking.

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = []
    visited.append(start)
    for neighbour in graph[start]:
        if neighbour not in visited:
            dfs(graph, neighbour, visited)
    return visited

print("DFS from A:", dfs(graph, 'A'))
# Out:
# DFS from A: ['A', 'B', 'D', 'E', 'F', 'C']

# %% [markdown]
# ## 4. Connectivity
#
# A graph is **connected** if there is a path between every pair of vertices.

# %%
def is_connected(graph):
    start = next(iter(graph))
    reachable = set(bfs(graph, start))
    return reachable == set(graph.keys())

print("Graph is connected:", is_connected(graph))
# Out:
# Graph is connected: True

# %% [markdown]
# ## Exercises
#
# 1. Implement a function to detect whether an undirected graph contains a cycle.
# 2. Count the number of connected components in a graph.
# 3. Determine whether a given graph is bipartite using BFS colouring.
